# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613) #set seed for reproducibility
x = np.arange(50)  #generate x values between 0 and 50
y = np.random.randint(0, 100,50)  #generate 50 random x values between 0 and 100

# %%
fig, ax = plt.subplots(figsize=(5, 3))  #set fig size
ax.scatter(x,y) #show data as scatter plot

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y) #show data as bar plot
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y) #show data as line plot

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

ax.set_title('Total growth over time', fontdict = font1, loc='left')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter( x, y, marker='*', color = "indigo") 
fig.show()
# Out:
# /var/folders/7p/mf_3kv8n7_b0_mszg1x7xcpm0000gn/T/ipykernel_1353/4228476701.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter( x, y, 
           marker='*', 
           color = "indigo", 
           linestyle='--', 
           linewidth=2) 

fig.show()
# Out:
# /var/folders/7p/mf_3kv8n7_b0_mszg1x7xcpm0000gn/T/ipykernel_1353/2651722176.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter( x, y, 
           marker='*', 
           color = "#7425b9", 
           linestyle='--', 
           linewidth=2) 

fig.show()
# Out:
# /var/folders/7p/mf_3kv8n7_b0_mszg1x7xcpm0000gn/T/ipykernel_1353/808774991.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot( x, y, 
           marker='*', 
           color = "#7425b9", 
           linestyle='--', 
           linewidth=2,
           markersize = 12,
           markeredgecolor='#fa9359',
           markerfacecolor='#fa9359') 
ax.grid(axis = 'y')
fig.show()
# Out:
# /var/folders/7p/mf_3kv8n7_b0_mszg1x7xcpm0000gn/T/ipykernel_1353/2641516522.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot( x, y, 
           marker='*', 
           color = "#7425b9", 
           linestyle='--', 
           linewidth=2,
           markersize = 12,
           markeredgecolor='#fa9359',
           markerfacecolor='#000000') 
ax.grid(axis = 'y', color = "blue", linewidth = 2, linestyle = '-.')
fig.show()
# Out:
# /var/folders/7p/mf_3kv8n7_b0_mszg1x7xcpm0000gn/T/ipykernel_1353/1181347207.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# y-axis in bold
rc('font', weight='bold')
 
# Values of each group
bars1 = [12, 28, 1, 8, 22]
bars2 = [28, 7, 16, 4, 10]
bars3 = [25, 3, 23, 25, 17]
 
# Heights of bars1 + bars2
bars = np.add(bars1, bars2).tolist()
 
# The position of the bars on the x-axis
r = [0,1,2,3,4]
 
# Names of group and bar width
names = ['A','B','C','D','E']
barWidth = 1
 
# Create brown bars
plt.bar(r, bars1, color='#7f6d5f', edgecolor='white', width=barWidth)
# Create green bars (middle), on top of the first ones
plt.bar(r, bars2, bottom=bars1, color='#557f2d', edgecolor='white', width=barWidth)
# Create green bars (top)
plt.bar(r, bars3, bottom=bars, color='#2d7f5e', edgecolor='white', width=barWidth)
 
# Custom X axis
plt.xticks(r, names, fontweight='bold')
plt.xlabel("group")
 
# Show graphic
plt.show()

# %% [markdown]
# I think that the graph above is aesthetic, substantive and perceptual.

# %%
## Customizing our plots (April 29)

# %%
np.random.seed(613)
x = np.arange(50)  #generate x values between 0 and 50
y1 = np.random.randint(0, 100,50)  #generate 50 random x values between 0 and 100
y2 = np.random.randint(0, 100,50)  #generate 50 random x values between 0 and 100

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, color='red')
ax.plot(x,y2,color='blue')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, color='red', label='person 1')
ax.plot(x,y2,color='blue', label='person 2')

ax.legend(loc='lower right')
ax.legend(loc='lower right', frameon = True, #add frame around the legend 
          fontsize = 12, #change font size 
          ncol = 2, #specify number of columns 
          shadow = True )

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, color='red', label='person 1')
ax.plot(x,y2,color='blue', label='person 2')
ax.legend(loc='lower right', bbox_to_anchor = (1,1))

# %%
#make a scatter plot instead
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, color='red', label='person 1')
ax.scatter(x,y2,color='blue', label='person 2')
ax.legend(loc='lower right')

ax.text(10, 56, 'This value is important', 
        ha = 'center',
        color='red',
        size = 12)
# Out:
# Text(10, 56, 'This value is important')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.axis([0,10,0,10])

ax.text(1,5, '. Data: (1,5)', transform = ax.transData)
ax.text(0.5,0.1, '. Data: (0.5,0.1)', transform = ax.transAxes)
ax.text(0.2,0.2, '. Data: (0.2,0.2)', transform = fig.transFigure)
# Out:
# Text(0.2, 0.2, '. Data: (0.2,0.2)')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, color='red', label='person 1')
ax.scatter(x,y2,color='blue', label='person 2')
ax.legend(loc='lower right')

ax.annotate('This is important!', xy=(10,95), xytext=(20,94),
            arrowprops=dict(arrowstyle = 'wedge', color = 'hotpink'))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, color='red', label='person 1')
ax.scatter(x,y2,color='blue', label='person 2')
ax.legend(loc='lower right')

ax.yaxis.set_major_locator(plt.NullLocator()) 
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, color='red', label='person 1')
ax.scatter(x,y2,color='blue', label='person 2')
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, color='red', label='person 1')
ax.scatter(x,y2,color='blue', label='person 2')
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

plt.xticks(rotation=45, ha='right')
# Out:
# (array([-20.,   0.,  20.,  40.,  60.]),
#  [Text(-20.0, 0, '−20'),
#   Text(0.0, 0, '0'),
#   Text(20.0, 0, '20'),
#   Text(40.0, 0, '40'),
#   Text(60.0, 0, '60')])

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, color='red', label='person 1')
ax.scatter(x,y2,color='blue', label='person 2')
ax.legend(loc='lower right')

font = {'family':'sans-serif','color':'indigo','size':20}
plt.xlabel('Shiny New x-axis!', fontsize=18,fontdict=font)
# Out:
# Text(0.5, 0, 'Shiny New x-axis!')

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, color='red', label='person 1')
ax.plot(x,y2,color='blue', label='person 2')
